# %% [raw]
# HR Analytics Project- Understanding the Attrition in HR

# %% [raw]
# Table of Contents
# 1. Overview
# 2. Importing Libraries & Data
# 3. Exploratory Data Analysis
# 4. Data Preprocessing
# 5. Model Development
#    5.1  Testing Candidate models
#    5.2  Hyperparameter tuning and Performance of model
#    5.3  Saving model
#    5.4  Predicting the Final Model
# 6. Conclusion
# 7. Reference

# %% [raw]
# 1. Overview

# %% [raw]
# Project Description:-
#
# Project Description:
# This project focuses on HR Analytics and its application in addressing employee attrition. We aim to understand the impact of attrition on organizations, particularly its cost implications and the challenges associated with a high employee turnover rate. Through data-driven analysis, we'll explore how HR Analytics can provide insights and solutions to mitigate attrition-related issues and enhance workforce stability and performance.
#
# Dataset Link- https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics

# %% [raw]
# 2.Importing Libraries & Data

# %%
# Importing neccessary librarys
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
# Load data set through pandas library
df= pd.read_csv(r"C:\Users\ganes\Downloads\IBM_HR_Attrition_Rate_Analytics-master\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %% [raw]
# 3.Exploratory Data Analyses

# %% [raw]
# Statistics of Dataset

# %%
# Data type of columns 
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# For checking dataset diemensions 
df.shape
# Out:
# (1470, 35)

# %%
# Available columns in dataset 
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Object data type columns 
do= df[['Attrition','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus','Over18', 'OverTime']]
do
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
# numerical columns of df
dn = df.drop(columns=do.columns)
dn
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
dn.columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [raw]
# Descriptive statistics

# %%
# Summarizing the distribution of the numerical variables.
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [raw]
# All columns have not in same scale. we have to normalize the data for model building. Some of coloumn contain outliers also like 'MonthlyIncome' .

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# For checking value count in label column 
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [raw]
# Data Visualization

# %% [raw]
# 1.Using Univariate Plots

# %%
# Define a list of numerical columns
numerical_columns = dn.columns.tolist()

# Define a list of object columns
object_columns = do.columns.tolist()

# Create univariate plots for numerical columns
for column in numerical_columns:
    plt.figure(figsize=(8, 4))  
    sns.distplot(df[column], kde=True) 
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# Create univariate plots for object columns
for column in object_columns:
    plt.figure(figsize=(8, 4))  
    sns.countplot(data=df, x=column)  
    plt.title(f'Count of {column}')
    plt.xlabel(column,fontsize=4)
    plt.ylabel('Count')
    plt.xticks(rotation=70) 
    plt.show()

# %% [raw]
# 2.Using Multivariate Plots

# %%
# Pairplot for pairwise relationships between numeric features
# Choose a subset of columns to include in the pair plot

columns_to_include = ['Age', 'Attrition', 'MonthlyIncome', 'JobSatisfaction', 'YearsAtCompany','DistanceFromHome','WorkLifeBalance']

# Create a pair plot for the selected columns
sns.pairplot(df[columns_to_include], hue='Attrition', diag_kind='kde')
plt.show()

# %%
# Heatmap to visualize correlations between features
correlation_matrix = df.corr()

plt.figure(figsize=(12, 10))
sns.set(font_scale=1.1)

# Create a mask to hide the lower triangle of the heatmap
mask = np.tri(*correlation_matrix.shape, k=-1, dtype=bool)

sns.heatmap(correlation_matrix, annot=True, cmap='Greens', linewidths=0.5,fmt=".2f", annot_kws={"size": 8}, mask=mask)

plt.yticks(rotation=0)   # Keep y-axis labels horizontal
plt.title('Correlation Heatmap')
plt.show()

# %% [raw]
# Joblevel is highely correlated with MonthlyIncome,TotalWorkingYears.MonthlyIncome is also realed with TotalWorkingYears.

# %%
# Create Boxplots
import seaborn as sns
import matplotlib.pyplot as plt

# Create boxplots to visualize numerical variables
plt.figure(figsize=(5, 4))
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.title('Boxplot of MonthlyIncome by Attrition')
plt.show()

# %%
# Get the list of all numerical columns
numerical_cols = dn.columns.tolist()

# Set the number of columns per row in the plot
cols_per_row = 3  

# Calculate the number of rows needed
num_cols = len(numerical_cols)
num_rows = (num_cols + cols_per_row - 1) // cols_per_row

# Create subplots with multiple rows and columns
fig, axes = plt.subplots(num_rows, cols_per_row, figsize=(16, 24))

# Flatten the axes array for easier iteration
axes = axes.ravel()

# Loop through numerical columns and create box plots
for i, col in enumerate(numerical_cols):
    sns.boxplot(data=df, y=col, ax=axes[i], palette='Set2')
    axes[i].set_title(f'Box Plot of {col}')
    axes[i].set_xlabel('')

# Remove empty subplots if there are any
for i in range(num_cols, num_rows * cols_per_row):
    fig.delaxes(axes[i])

# Adjust spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# 4.Data Preprocessing

# %% [markdown]
# checking for null value in dataset nan,none

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Outlier removal

# %%
# Create a copy of the DataFrame to preserve the original data
df_no_outliers = df

def remove_outliers_iqr(data, col_name, lower_factor=1.5, upper_factor=1.5):
    q1 = data[col_name].quantile(0.25)
    q3 = data[col_name].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - lower_factor * iqr
    upper_bound = q3 + upper_factor * iqr
    return data[(data[col_name] >= lower_bound) & (data[col_name] <= upper_bound)]

# Apply function to each column
numerical_columns 
for col in numerical_columns:
    df_no_outliers = remove_outliers_iqr(df_no_outliers, col)

# %%
# shape of dataset after outlier removal 
df_no_outliers.shape
# Out:
# (699, 35)

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# Around half of data ia loss. Also dataset have certain uniquness in data the build the robustness of model for these values.
# We keep the original dataset df .

# %% [markdown]
# skewness removal

# %%
# Calculate the skewness of each column
skewness = df.skew()
print("Skewness of Columns:")
print(skewness)
# Out:
# Skewness of Columns:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# ...

# %% [markdown]
# Some of columns have skewness above 0.5 , so we apply box-cox and sqrt method for skewness removal .

# %%
# Define a threshold for skewness (e.g., 0.5) above which you consider a column as skewed
skew_threshold = 0.5

skewed_columns = skewness[abs(skewness) > skew_threshold].index.tolist()

# Apply skewness correction to the skewed columns using a transformation like the Box-Cox method
for col in skewed_columns:
    # Check for negative values (Box-Cox requires all values to be positive)
    if (df[col] > 0).all():
        df[col] = np.log1p(df[col])  # Log transformation
    else:
        df[col] = df[col] ** 0.5  # Square root transformation

# %% [markdown]
# Encoding of object datatype column

# %% [markdown]
# We are using encoder according to respective need and type of having category data in columns.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# List of categorical columns to label encode
categorical_cols = ['Gender', 'MaritalStatus', 'Over18', 'OverTime']

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %% [markdown]
# Here we are using mapping function for ordinal data for relationship among category data.

# %%
# Define custom mappings for ordinal encoding
education_field_mapping = {
    'Life Sciences': 5,
    'Medical': 4,
    'Marketing': 3,
    'Technical Degree': 2,
    'Other': 1,
    'Human Resources': 0
}

business_travel_mapping = {
    'Travel_Frequently': 2,
    'Travel_Rarely': 1,
    'Non-Travel': 0
}

# Apply ordinal encoding
df['EducationField'] = df['EducationField'].map(education_field_mapping)
df['BusinessTravel'] = df['BusinessTravel'].map(business_travel_mapping)

# %% [markdown]
# Due to high number of unique category in columns . We use binary encoder to balance the number of columns in dataset.

# %%
pip install category-encoders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import category_encoders as ce

# List of categorical columns to binary encode
categorical_cols = ['Department', 'JobRole']

# Initialize binary encoder
binary_encoder = ce.BinaryEncoder(cols=categorical_cols)

# Apply binary encoding
df = binary_encoder.fit_transform(df)

# %%
df.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate  Department_0  Department_1  \
# 0   41       Yes               1       1102             0             1
# 1   49        No               2        279             1             0
# 2   37       Yes               1       1373             1             0
# 3   33        No               2       1392             1             0
# 4   27        No               1        591             1             0
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0          0.693147          2               5              1  ...
# 1          2.197225          1               5              1  ...
# 2          1.098612          2               1              1  ...
# 3          1.386294          4               5              1  ...
# 4          1.098612          1               4              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80               0.0
# ...

# %% [markdown]
# Normalization of data

# %% [markdown]
# We use Standard Scaler instead using Min-Max Scaler for less effected by outliers and normal distribution around mean=0 ,std=1.

# %%
from sklearn.preprocessing import StandardScaler

# Split the data into features (X) and target (y)
x = df.drop(columns='Attrition')
Y = df["Attrition"]

# %%
# Normalize the feature columns using StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(x)

# %% [markdown]
# 5.Model Development

# %% [markdown]
# 5.1 Testing Candidate models

# %%
#Importing Machine learning Model library
from sklearn.svm  import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier , AdaBoostClassifier , BaggingClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score,roc_curve

# %% [markdown]
# Splitting Data into train test

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.30, random_state=59)

# %% [markdown]
# Classification Algorithms

# %% [markdown]
# Logistics Regression

# %%
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('Logistics Regression')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
print('Confusion matrix :',confusion_matrix(Y_test, y_pred))
# Out:
# Logistics Regression
# Accuracy Score : 0.9047619047619048
# Confusion matrix : [[364   7]
#  [ 35  35]]

# %% [markdown]
# Decision Tree Classifier

# %%
DTC=DecisionTreeClassifier()
DTC.fit(X_train,Y_train)
y_pred=DTC.predict(X_test)
print('Decision Tree Classifier')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
# Out:
# Decision Tree Classifier
# Accuracy Score : 0.7981859410430839

# %% [markdown]
# Random Forest Classifier

# %%
RFC=RandomForestClassifier()
RFC.fit(X_train,Y_train)
y_pred=RFC.predict(X_test)
print('Random Forest Classifier')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
Accu = accuracy_score(Y_test, y_pred)
# Out:
# Random Forest Classifier
# Accuracy Score : 0.8639455782312925

# %% [markdown]
# AdaBoost Classifier

# %%
Abc=AdaBoostClassifier()
Abc.fit(X_train,Y_train)
y_pred=Abc.predict(X_test)
print('AdaBoost Classifier')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
# Out:
# AdaBoost Classifier
# Accuracy Score : 0.8866213151927438

# %% [markdown]
# Support Vector Machine Classifier

# %%
svc= SVC()
svc.fit(X_train,Y_train)
y_pred = svc.predict(X_test)
print('Support Vector Machine Classifier')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
# Out:
# Support Vector Machine Classifier
# Accuracy Score : 0.8775510204081632

# %% [markdown]
# Bagging Classifier

# %%
BC= BaggingClassifier()
BC.fit(X_train,Y_train)
y_pred = BC.predict(X_test)
print('Bagging Classifier')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
Accub = accuracy_score(Y_test, y_pred)
# Out:
# Bagging Classifier
# Accuracy Score : 0.8616780045351474

# %% [markdown]
# Logistics Regression gives highest Accuracy Score :  0.9047 .

# %% [markdown]
# Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# cross validation score for Logistics Regression
# By default CV=5 and Scoring parameter is accuracy 

score= cross_val_score(log_reg,X,Y)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is -', Accu-score.mean() )
# Out:
# [0.89455782 0.8707483  0.87755102 0.88435374 0.90136054]
# 0.8857142857142858
# Difference between accuracy score and cross validation score is - -0.02176870748299331

# %%
# cross validation score for random forest classifier
score= cross_val_score(RFC,X,Y)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is -', Accu-score.mean() )
# Out:
# [0.86054422 0.85714286 0.86734694 0.85714286 0.86054422]
# 0.8605442176870748
# Difference between accuracy score and cross validation score is - 0.003401360544217691

# %%
# cross validation score for Bagging Classifier
score= cross_val_score(BC,X,Y)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is -',Accub-score.mean() )
# Out:
# [0.81972789 0.84353741 0.84693878 0.82653061 0.87755102]
# 0.8428571428571429
# Difference between accuracy score and cross validation score is - 0.018820861678004563

# %%
# cross validation score for AdaBoost Classifier
score= cross_val_score(Abc,X,Y)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is -',Accub-score.mean() )
# Out:
# [0.83673469 0.86394558 0.8537415  0.88095238 0.84013605]
# 0.8551020408163266
# Difference between accuracy score and cross validation score is - 0.006575963718820854

# %%
# cross validation score for Support Vector Machine Classifier
score= cross_val_score(svc,X,Y)
print(score)
print(score.mean())
print('Difference between accuracy score and cross validation score is -',Accub-score.mean() )
# Out:
# [0.87414966 0.86734694 0.8707483  0.88095238 0.88095238]
# 0.8748299319727891
# Difference between accuracy score and cross validation score is - -0.013151927437641708

# %%
So our best model is Logistics Regression which have less difference between accuracy score and cross validation score.
Also accuracy is high compare to other which have very less difference between accuracy score and cross validation score.

# %% [markdown]
# 5.2 Hyperparameter tuning and Performance of model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Define the hyperparameters and their possible values to search
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Regularization parameter
    'penalty': ['l1', 'l2'],  # Regularization type
    'solver': ['liblinear'],  # Solver for logistic regression
}

# %%
# Create a Logistic Regression model
logistic_reg = LogisticRegression()

# Create a Grid Search Cross-Validation object
grid_search = GridSearchCV(estimator=logistic_reg, param_grid=param_grid, cv=5, scoring='accuracy')

# Fit the Grid Search to your training data
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='accuracy')

# %%
# Print the best hyperparameters and the corresponding accuracy score
print("Best Hyperparameters: ", grid_search.best_params_)
print("Best Accuracy Score: ", grid_search.best_score_)

# Get the best model with the best hyperparameters
best_logistic_reg = grid_search.best_estimator_

# Evaluate the best model on the test set
accuracy = best_logistic_reg.score(X_test, Y_test)
print("Test Set Accuracy: ", accuracy)
# Out:
# Best Hyperparameters:  {'C': 1, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Accuracy Score:  0.8785176414870944
# Test Set Accuracy:  0.9070294784580499

# %% [markdown]
# Final Model

# %%
best_hyperparameters = grid_search.best_params_

# %%
Final_model = LogisticRegression(**best_hyperparameters, random_state=59)
Final_model.fit(X_train,Y_train)
y_pred=Final_model.predict(X_test)
print('Final Model Logistic Regression')
print('Accuracy Score :', accuracy_score(Y_test, y_pred))
print('Confusion matrix :',confusion_matrix(Y_test, y_pred))
print('classification Report :',classification_report(Y_test, y_pred))
# Out:
# Final Model Logistic Regression
# Accuracy Score : 0.9070294784580499
# Confusion matrix : [[366   5]
#  [ 36  34]]
# classification Report :               precision    recall  f1-score   support
#
#           No       0.91      0.99      0.95       371
#          Yes       0.87      0.49      0.62        70
#
#     accuracy                           0.91       441
#    macro avg       0.89      0.74      0.79       441
# weighted avg       0.90      0.91      0.90       441

# %% [markdown]
# 5.3 Saving model

# %%
import joblib 
joblib.dump(Final_model,'HR Analytics Project.pkl')
# Out:
# ['HR Analytics Project.pkl']

# %% [markdown]
# 5.4 Predicting the Final Model

# %%
prediction = Final_model.predict(X_test)

# %%
Actual = np.array(Y_test)
df_pred = pd.DataFrame()
df_pred["Predicted Attrition"] = prediction
df_pred["Actual Attrition"] = Actual
df_pred.head(10)
# Out:
#   Predicted Attrition Actual Attrition
# 0                  No               No
# 1                  No               No
# 2                  No               No
# 3                  No               No
# 4                  No               No
# 5                  No               No
# 6                  No               No
# 7                  No               No
# 8                  No               No
# 9                  No               No

# %% [markdown]
# Model is predicted accurately the employee attrition.
# We can understand the impact of attrition on organizations, particularly its cost implications and the challenges associated with a high employee turnover rate. Through data-driven analysis .
